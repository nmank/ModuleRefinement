# %%
import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns
from matplotlib import pyplot as plt

from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
svm_all = pd.read_csv('../results/hiD/refined_svm_score.csv', index_col = 0)

# %%
svm_all
# Out:
#     Relative Gain  Fold    Prototype  Data Dimension  Center Dimension  \
# 0        0.002294     2    flag_mean               2                 4
# 1        0.016027     0  flag_median               2                 8
# 2        0.022580     3  flag_median               2                 8
# 3        0.033392     4  flag_median               2                 8
# 4        0.114927     4  flag_median               2                 4
# 5        0.183892     4  flag_median               2                 8
# 6       -0.110097     4    flag_mean               2                 8
# 7        0.110384     1  flag_median               2                 4
# 8        0.058436     1    flag_mean               2                 8
# 9       -0.070973     3    flag_mean               2                 8
# 10      -0.038715     3  flag_median               2                 8
#
#                            Data Set
# 0        gse73072_hrv_48_64_control
# 1        gse73072_hrv_48_64_control
# 2        gse73072_hrv_48_64_control
# 3   gse73072_hrv_48_64_shedder48_64
# 4                  salmonella_Liver
# 5                  salmonella_Liver
# 6      salmonella_Liver_susceptible
# 7         salmonella_Liver_tolerant
# 8         salmonella_Liver_tolerant
# 9         salmonella_Liver_tolerant
# 10        salmonella_Liver_tolerant

# %%
go_all = pd.read_csv('../results/hiD/refined_go_score.csv', index_col = 0)

# %%
go_all
# Out:
#     Relative Gain  Fold    Prototype  Data Dimension  Center Dimension  \
# 0       -0.206171     2    flag_mean               2                 4
# 1       -0.128961     0  flag_median               2                 8
# 2       -0.095984     3  flag_median               2                 8
# 3       -0.048204     4  flag_median               2                 8
# 4       -0.529593     4  flag_median               2                 4
# 5       -0.380228     4  flag_median               2                 8
# 6       -0.274245     4    flag_mean               2                 8
# 7        3.946135     0  flag_median               2                 8
# 8        5.204132     1  flag_median               2                 8
# 9        5.187908     2  flag_median               2                 8
# 10       3.710102     3  flag_median               2                 8
# 11       4.958599     4  flag_median               2                 8
# 12      -0.393496     1  flag_median               2                 4
# 13      -0.115844     1    flag_mean               2                 8
# 14      -0.249656     3    flag_mean               2                 8
# 15      -0.129434     3  flag_median               2                 8
#
#                            Data Set
# 0        gse73072_hrv_48_64_control
# 1        gse73072_hrv_48_64_control
# 2        gse73072_hrv_48_64_control
# 3   gse73072_hrv_48_64_shedder48_64
# 4                  salmonella_Liver
# 5                  salmonella_Liver
# 6      salmonella_Liver_susceptible
# 7      salmonella_Liver_susceptible
# 8      salmonella_Liver_susceptible
# 9      salmonella_Liver_susceptible
# 10     salmonella_Liver_susceptible
# 11     salmonella_Liver_susceptible
# 12        salmonella_Liver_tolerant
# 13        salmonella_Liver_tolerant
# 14        salmonella_Liver_tolerant
# 15        salmonella_Liver_tolerant
